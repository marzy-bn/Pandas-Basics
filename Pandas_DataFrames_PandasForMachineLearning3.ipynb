# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %%
my_data = randn(4,3) #rows, cols
my_rows = ["A","B","C","D"]
my_cols = ["Monday","Tuesday","Friday"]

# %%
#create dataframe
my_df = pd.DataFrame(my_data, my_rows, my_cols)
my_df
# Out:
#      Monday   Tuesday    Friday
# A  0.725911  1.174088 -0.141848
# B  0.613807 -0.116011 -0.359258
# C -0.920747  1.240757 -0.616636
# D -1.750953  1.449076 -0.466094

# %%
#import csv file
my_df2 = pd.read_csv('/content/drive/MyDrive/008-Interviews/Pandas_Projects/Data/Flavors.csv')
my_df2
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
#pull out rows
my_df2.loc[0]
# Out:
# Flavor            Mint Chocolate Chip
# Base Flavor                   Vanilla
# Liked                             Yes
# Flavor Rating                    10.0
# Texture Rating                    8.0
# Total Rating                     18.0
# Name: 0, dtype: object

# %%
#pull out multiple rows
my_df2.loc[[0,5,8]]
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 5           5.7
# 8          15.3
