# %%
import pandas as pd
import numpy as np

# %%
#import csv file
my_df = pd.read_csv('/content/drive/MyDrive/008-Interviews/Pandas_Projects/Data/Flavors.csv')
my_df
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
#grab first 2 rows
my_df.head()
# Out:
#                 Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0  Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1            Chocolate   Chocolate   Yes            8.8             7.6
# 2              Vanilla     Vanilla    No            4.7             5.0
# 3         Cookie Dough     Vanilla   Yes            6.9             6.5
# 4           Rocky Road   Chocolate   Yes            8.2             7.0
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2

# %%
#grab certain number of first rows
my_df.head(9)
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
#grab last 5 rows
my_df.tail()
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
#grab certain number of last rows
my_df.tail(8)
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Flavor          9 non-null      object
#  1   Base Flavor     9 non-null      object
#  2   Liked           9 non-null      object
#  3   Flavor Rating   9 non-null      float64
#  4   Texture Rating  9 non-null      float64
#  5   Total Rating    9 non-null      float64
# dtypes: float64(3), object(3)
# memory usage: 560.0+ bytes

# %%
#get shape of rows and cols
my_df.shape
# Out:
# (9, 6)

# %%
#get number of dimesnions
my_df.ndim
# Out:
# 2

# %%
#get the column datatypes
my_df.dtypes
# Out:
# Flavor             object
# Base Flavor        object
# Liked              object
# Flavor Rating     float64
# Texture Rating    float64
# Total Rating      float64
# dtype: object

# %%
#get some stats about the data
my_df.describe()
# Out:
#        Flavor Rating  Texture Rating  Total Rating
# count         9.0000        9.000000      9.000000
# mean          6.6000        6.177778     12.800000
# std           2.5387        1.478832      4.030509
# min           2.3000        3.400000      5.700000
# 25%           4.7000        5.000000      9.700000
# 50%           6.9000        6.500000     13.400000
# 75%           8.2000        7.100000     15.300000
# max          10.0000        8.000000     18.000000

# %%
#describe a specific column
my_df['Flavor'].describe()
# Out:
# count                       9
# unique                      9
# top       Mint Chocolate Chip
# freq                        1
# Name: Flavor, dtype: object

# %%
#select specific column using dot notation
my_df.Flavor
# Out:
# 0       Mint Chocolate Chip
# 1                 Chocolate
# 2                   Vanilla
# 3              Cookie Dough
# 4                Rocky Road
# 5                 Pistachio
# 6               Cake Batter
# 7                Neapolitan
# 8    Chocolte Fudge Brownie
# Name: Flavor, dtype: object

# %%
#select specific column using location
my_df.iloc[:,0]
# Out:
# 0       Mint Chocolate Chip
# 1                 Chocolate
# 2                   Vanilla
# 3              Cookie Dough
# 4                Rocky Road
# 5                 Pistachio
# 6               Cake Batter
# 7                Neapolitan
# 8    Chocolte Fudge Brownie
# Name: Flavor, dtype: object
