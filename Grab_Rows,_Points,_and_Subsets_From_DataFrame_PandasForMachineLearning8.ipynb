# %%
import pandas as pd
import numpy as np
#import csv
my_df = pd.read_csv('/content/drive/MyDrive/008-Interviews/Pandas_Projects/Data/dog_data_short.csv')
my_df
# Out:
#                  Breed        Color  DogName  OwnerZip
# 0             COCKAPOO        BROWN  CHARLEY     15236
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS      BRINDLE     EICH     15238
# 3                MIXED  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %%
#Grab Row method 1 location
my_df.loc[2]
# Out:
# Breed       BELG MALINOIS
# Color             BRINDLE
# DogName              EICH
# OwnerZip            15238
# Name: 2, dtype: object

# %%
#Grab Row method 2 index location
my_df.iloc[3]
# Out:
# Breed             MIXED
# Color       BLACK/BROWN
# DogName           ARROW
# OwnerZip          15104
# Name: 3, dtype: object

# %%
#specific points (row an col)
my_df.loc[1,'DogName']
# Out:
# 'TACODA'

# %%
#subset
my_df.loc[[1,3,4],['DogName','Breed','Color']]
# Out:
#   DogName                Breed        Color
# 1  TACODA         GER SHEPHERD  BLACK/BROWN
# 3   ARROW                MIXED  BLACK/BROWN
# 4  OAKLEY  AM PIT BULL TERRIER  WHITE/BROWN
